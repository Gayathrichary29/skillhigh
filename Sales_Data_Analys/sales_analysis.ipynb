# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data.csv")
df
# Out:
#          Date Product  Sales Promotion
# 0  2024-01-01  Mobile  15000       Yes
# 1  2024-01-02  Laptop  30000        No
# 2  2024-01-03  Tablet  12000       Yes
# 3  2024-02-01  Mobile  18000       Yes
# 4  2024-02-05  Laptop  35000        No
# 5  2024-03-10  Tablet  15000       Yes
# 6  2024-03-15  Mobile  22000        No
# 7  2024-04-01  Laptop  40000       Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8 non-null      object
#  1   Product    8 non-null      object
#  2   Sales      8 non-null      int64
#  3   Promotion  8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 388.0+ bytes

# %%
df.head()
# Out:
#          Date Product  Sales Promotion
# 0  2024-01-01  Mobile  15000       Yes
# 1  2024-01-02  Laptop  30000        No
# 2  2024-01-03  Tablet  12000       Yes
# 3  2024-02-01  Mobile  18000       Yes
# 4  2024-02-05  Laptop  35000        No

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.isnull().sum()
# Out:
# Date         0
# Product      0
# Sales        0
# Promotion    0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
total_sales = df['Sales'].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 187000

# %%
daily_sales = df.groupby('Date')['Sales'].sum()

# %%
plt.figure(figsize=(10,5))
plt.plot(daily_sales)
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
df['Month'] = df['Date'].dt.month

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

# %%
plt.figure(figsize=(8,5))
plt.bar(monthly_sales.index, monthly_sales.values)
plt.title("Monthly Sales Analysis")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
product_sales = df.groupby('Product')['Sales'].sum()

# %%
plt.figure(figsize=(8,5))
product_sales.plot(kind='bar')
plt.title("Product Wise Sales")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %%
promotion_sales = df.groupby('Promotion')['Sales'].sum()

# %%
plt.figure(figsize=(6,4))
promotion_sales.plot(kind='bar')
plt.title("Impact of Promotion on Sales")
plt.xlabel("Promotion")
plt.ylabel("Sales")
plt.show()
